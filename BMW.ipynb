# %% [markdown]
# <a href="https://colab.research.google.com/github/olharius/Random_stuff/blob/main/BMW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/rerkki/data-analytics-ml/refs/heads/main/datasets/bmw.csv", encoding='latin-1')
df
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1       6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2       5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3       1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4       7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10776         X3  2016  19000    Automatic    40818   Diesel  150  54.3
# 10777   5 Series  2016  14600    Automatic    42947   Diesel  125  60.1
# 10778   3 Series  2017  13100       Manual    25468   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic    45000   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic    59432   Diesel  125  57.6
#
#        engineSize
# 0             2.0
# 1             2.0
# 2             3.0
# 3             1.5
# ...

# %%
print('Descriptive statistics for Mileage by Fuel Type:')
display(df.groupby('fuelType')['mileage'].describe())

print('\nDescriptive statistics for Engine Size by Fuel Type:')
display(df.groupby('fuelType')['engineSize'].describe())

print('\nDescriptive statistics for MPG by Fuel Type:')
display(df.groupby('fuelType')['mpg'].describe())
# Out:
# Descriptive statistics for Mileage by Fuel Type:
#            count          mean           std      min       25%      50%  \
# fuelType
# Diesel    7027.0  29852.804042  26386.895351      1.0   7273.50  24600.0
# Electric     3.0  19925.333333   9743.527099   9990.0  15155.50  20321.0
# Hybrid     298.0  23400.530201  24642.860166      5.0   4964.75  16900.0
# Other       36.0  44760.638889  15151.026600  19178.0  32291.75  44351.5
# Petrol    3417.0  16524.097454  19591.399460      3.0   3412.00   9097.0
#
#                75%       max
# fuelType
# Diesel    44989.00  214000.0
# Electric  24893.00   29465.0
# Hybrid    34000.75  178987.0
# Other     54037.75   78878.0
# Petrol    23910.00  141000.0
# Descriptive statistics for Engine Size by Fuel Type:
#            count      mean       std  min  25%  50%  75%  max
# fuelType
# Diesel    7027.0  2.197794  0.466403  0.0  2.0  2.0  2.0  3.0
# Electric     3.0  0.333333  0.577350  0.0  0.0  0.0  0.5  1.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(2, 2, figsize=(18, 12))

# Boxplot of Mileage
sns.boxplot(y=df['mileage'], ax=axes[0, 0])
axes[0, 0].set_title('Boxplot of Mileage')
axes[0, 0].set_ylabel('Mileage')

# Boxplot of MPG
sns.boxplot(y=df['mpg'], ax=axes[0, 1])
axes[0, 1].set_title('Boxplot of MPG')
axes[0, 1].set_ylabel('MPG')

# Boxplot of Engine Size
sns.boxplot(y=df['engineSize'], ax=axes[1, 0])
axes[1, 0].set_title('Boxplot of Engine Size')
axes[1, 0].set_ylabel('Engine Size')

# Boxplot of MPG by Fuel Type
sns.boxplot(x=df['fuelType'], y=df['mpg'], ax=axes[1, 1])
axes[1, 1].set_title('Boxplot of MPG by Fuel Type')
axes[1, 1].set_xlabel('Fuel Type')
axes[1, 1].set_ylabel('MPG')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(x=df['fuelType'], y=df['mpg'])
plt.title('Boxplot of MPG by Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('MPG')
plt.show()

# %% [markdown]
# **Tehtävä: **
# Tutki muita riippuvuuksia vastaavaan tapaan kopioimalla koodeja ja tekemällä samanlaisia visualisaatioita. Esim: kulutus (mpg) vuosimallista riippuen, hinta/vuosimalli, hinta/matkamittarin lukema, matkamittarin lukema/vuosimalli jne.
#
# Kirjoita jokaisesta tekemästäsi kuvaajasta selitys, minkälaisia riippuvuuksia havaitset.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(x=df['engineSize'], y=df['tax'])
plt.title('Boxplot of tax by engine size')
plt.xlabel('Egine size')
plt.ylabel('tax')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(x=df['fuelType'], y=df['mileage'])
plt.title('Boxplot of mileage by Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('mileage')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6)) # Increased figure width for better label spacing
sns.boxplot(x=df['year'], y=df['mileage'])
plt.title('Boxplot of mileage by year')
plt.xlabel('Year model')
plt.ylabel('Mileage')

# Get unique years and set ticks/labels for every 3rd year
# This condenses the labels without removing data points from the plot
years = sorted(df['year'].unique())
plt.xticks(ticks=range(0, len(years), 3), labels=years[::3], rotation=45)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(x=df['year'], y=df['price'])
plt.title('Boxplot of Price by Year model')
plt.xlabel('Year model')
plt.ylabel('Price')

# Get unique years and set ticks/labels for every 3rd year
# This condenses the labels without removing data points from the plot
years = sorted(df['year'].unique())
plt.xticks(ticks=range(0, len(years), 3), labels=years[::3], rotation=45)

plt.tight_layout()
plt.show()
